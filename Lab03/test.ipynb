# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

X, Y = make_classification(200, 2, 2, 0, weights=[.5, .5], random_state=0)

# %%
plt.scatter(X[:,0], X[:,1], c=Y)

# %%
from perceptron import perceptron

# %%
p = perceptron(learning_rate=0.01, epochs=100)
weights = p.fit(X, Y)

# %%
weights
# Out:
# array([-0.01      ,  0.04847677,  0.0079275 ])

# %%
p.predict(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-2ff11cfac24d> in <module>
# ----> 1 p.predict(X)
#
# ~/Documents/Machine Learning/PeilinZhong/Lab03/perceptron.py in predict(self, X)
#      27     def predict(self, X):
#      28         s = np.dot(X, self.weights[1:]) + self.weights[0]
# ---> 29         return self.activation(s)
#      30
#      31     def activation(self, x):
#
# ~/Documents/Machine Learning/PeilinZhong/Lab03/perceptron.py in activation(self, x)
#      31     def activation(self, x):
#      32         result = self.sigmoid(x)
# ---> 33         if result > 0.5:
#      34             return 1
#      35         else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
